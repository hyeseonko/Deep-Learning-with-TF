# %% [markdown]
# # Crash Course Review
#
# [Question 1]
# import numpy, pandas, matplotlib and sklearn.
# Also set visualisation to be shown inline in the notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl

# %matplotlib inline

# %% [markdown]
# [Solution]
#
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.model_selection import train_test_split
#
# ---------------------------------------------------
# [Question 2] Set Numpy's Random Seed to 101

# %%
np.random.seed(101)

# %% [markdown]
# [Solution]
# np.random.seed(101)
#
# ---------------------------------
# [Question 3] Create a Numpy Matrix of 100 rows by 5 columns consisting of random integers from 1-100. (Keep in mind that the upper limit may be exclusive)

# %%
mat = np.random.randint(1,100,(100,5))

# %% [markdown]
# [Solution]
# mat = np.random.randint(1,101,(100,5))
#
# ----------------------------------------------
# [Question 4]
# Create a 2-D visualisation using plt.imshow of the numpy matrix with a colorbar. Add a title to your plot. Bonus: Figure out how to change aspect of the imshow() plot.

# %%
plt.imshow(mat)
plt.colorbar()
plt.title('My Plot')
# Out:
# Text(0.5,1,'My Plot')

# %% [markdown]
# [Solution]
# plt.imshow(mat, aspect=0.05)
# plt.colorbar()
# plt.title("My plot")
#
# -----------------------------------------
# [Question 5]
# Now use pd.DataFrame() to read in this numpy array as a dataframe. Simple pass in the numpy array into that function to get back a dataframe. Pandas will auto label the columns to 0-4

# %%
df=pd.DataFrame(data=mat)
df
# Out:
#      0   1   2   3   4
# 0   20  70   2  78  64
# 1   88  29  71   6   4
# 2   13  63  27  97  62
# 3   88  75  98  65  96
# 4    4  89  60  39  30
# 5   32  89  58  10  63
# 6   32  14  36  48   3
# 7   18  51  23  31  37
# 8   23  98  52  39  29
# 9    5   1  13  91   3
# 10   8  45  55  50  77
# 11  99   4  33  92  44
# 12   8  43  67  10   6
# 13  27  67  23  48  28
# 14  47  15  53  75  55
# 15   4  95  37  64  42
# 16  19  38  46  83  48
# 17  67  98  21  10  88
# 18  41  14  96  17  39
# 19  88  73  61  79  54
# 20  49  84  91  42  85
# 21  79  56  71  94  58
# 22  87  68   9  48  71
# 23  40  54   6  41  89
# 24  59  13  71   6  83
# 25   9  61  59  46  93
# 26  86  45  63  40  39
# 27  55  99  81  94  17
# 28  38  59  41  73  73
# 29  23  43  39  46  17
# ..  ..  ..  ..  ..  ..
# 70  80  60  34  34  12
# 71  45  44  94   4  40
# 72  78   4  59  52  33
# 73  47   9  10  14  64
# 74  60  80   6  34  48
# 75  30  80  63  26  44
# 76  47  95  69  56  70
# 77  42  42  15  48   4
# ...

# %% [markdown]
# [Solution] Correct
#
# --------------------------------
#
# [Question 6]
# Now create a scatter plot using pandas of the 0 column vs. the 1 column.

# %%
df.plot(x=0, y=1, kind='scatter')

# %% [markdown]
# [Solution]
# df.plot(x=0, y=1, kind='scatter')
#
# -----------------
#
# [Question 7]
# Now scale the data to have a min of 0 and a max of 1 using scikit-learn

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_model=MinMaxScaler()
scaler_model.fit_transform(df)
# Out:
# array([[ 0.18556701,  0.70408163,  0.        ,  0.79787234,  0.64210526],
#        [ 0.88659794,  0.28571429,  0.71134021,  0.03191489,  0.01052632],
#        [ 0.11340206,  0.63265306,  0.25773196,  1.        ,  0.62105263],
#        [ 0.88659794,  0.75510204,  0.98969072,  0.65957447,  0.97894737],
#        [ 0.02061856,  0.89795918,  0.59793814,  0.38297872,  0.28421053],
#        [ 0.30927835,  0.89795918,  0.57731959,  0.07446809,  0.63157895],
#        [ 0.30927835,  0.13265306,  0.35051546,  0.4787234 ,  0.        ],
#        [ 0.16494845,  0.51020408,  0.21649485,  0.29787234,  0.35789474],
#        [ 0.21649485,  0.98979592,  0.51546392,  0.38297872,  0.27368421],
#        [ 0.03092784,  0.        ,  0.11340206,  0.93617021,  0.        ],
#        [ 0.06185567,  0.44897959,  0.54639175,  0.5       ,  0.77894737],
#        [ 1.        ,  0.03061224,  0.31958763,  0.94680851,  0.43157895],
#        [ 0.06185567,  0.42857143,  0.67010309,  0.07446809,  0.03157895],
# ...

# %% [markdown]
# [Solution]
# scaler=MinMaxScaler()
# result=scaler.fit_transform(df)
# result
#
# -------------------------------------------
# [Question 8]
# Using your previously created DataFrame, use df.columns =[...] to rename the pandas columns to be ['f1', 'f2', 'f3', 'f4', 'label']. Then perform a train/test split with scikitlearn

# %%
from sklearn.model_selection import train_test_split
df=pd.DataFrame(data=mat, columns=['f1', 'f2', 'f3', 'f4', 'label'])

# %%
x = df[['f1', 'f2', 'f3', 'f4']]
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     x, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (70, 4)

# %% [markdown]
# [Solution]
# df.columns=['f1', 'f2', 'f3', 'f4']
# df.head(10) # can see 10 first rows
# X = df[['f1', 'f2', 'f3', 'f4']]
# y=df['label']
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
#
# # Completed!
